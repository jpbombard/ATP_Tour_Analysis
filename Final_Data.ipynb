# %% [markdown]
# # Build Final Dataframe for analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import statsmodels.api as sm
import statsmodels.formula.api as smf
from scipy import stats
import matplotlib.pyplot as plt
from pandasql import sqldf
import sqlite3 
import datetime as dt
import plotly.express as px

# %%
con = sqlite3.connect('/Users/julianbombard/Desktop/Data Analytics Course/Capstone/database/ATP_Tour')
df = pd.read_sql_query('''Select *
                       From player_match_stats''', con)

con.close()

df.head()
# Out:
#    player_id    match_id  year  month      player_name  height hand  \
# 0     105357  2015-339_1  2015      1     John Millman     183    R
# 1     103813  2015-339_2  2015      1  Jarkko Nieminen     185    L
# 2     105902  2015-339_3  2015      1  James Duckworth     183    R
# 3     104871  2015-339_4  2015      1    Jeremy Chardy     188    R
# 4     105373  2015-339_5  2015      1    Martin Klizan     191    L
#
#   tourney_name tourney_level surface  ... bp_saved  bp_faced  rank  \
# 0     Brisbane             A    Hard  ...        1         1   153
# 1     Brisbane             A    Hard  ...        4         7    73
# 2     Brisbane             A    Hard  ...        2         3   125
# 3     Brisbane             A    Hard  ...        0         0    31
# 4     Brisbane             A    Hard  ...        6         8    34
#
#    rank_points  won  first_sv_pct  first_sv_win_pct  second_sv_win_pct  \
# 0          328    1      0.545455          0.791667           0.700000
# 1          689    1      0.641304          0.661017           0.515152
# 2          430    1      0.600000          0.740741           0.611111
# 3         1195    1      0.735849          0.794872           0.785714
# 4         1094    1      0.607692          0.696203           0.529412
#
#    total_sv_win_pct  bp_save_pct
# 0          0.750000     1.000000
# 1          0.608696     0.571429
# 2          0.688889     0.666667
# 3          0.792453          NaN
# 4          0.630769     0.750000
#
# [5 rows x 29 columns]

# %%
df['won'] = df['won'].astype('bool')
df.head()
# Out:
#    player_id    match_id  year  month      player_name  height hand  \
# 0     105357  2015-339_1  2015      1     John Millman     183    R
# 1     103813  2015-339_2  2015      1  Jarkko Nieminen     185    L
# 2     105902  2015-339_3  2015      1  James Duckworth     183    R
# 3     104871  2015-339_4  2015      1    Jeremy Chardy     188    R
# 4     105373  2015-339_5  2015      1    Martin Klizan     191    L
#
#   tourney_name tourney_level surface  ... bp_saved  bp_faced  rank  \
# 0     Brisbane             A    Hard  ...        1         1   153
# 1     Brisbane             A    Hard  ...        4         7    73
# 2     Brisbane             A    Hard  ...        2         3   125
# 3     Brisbane             A    Hard  ...        0         0    31
# 4     Brisbane             A    Hard  ...        6         8    34
#
#    rank_points   won  first_sv_pct  first_sv_win_pct  second_sv_win_pct  \
# 0          328  True      0.545455          0.791667           0.700000
# 1          689  True      0.641304          0.661017           0.515152
# 2          430  True      0.600000          0.740741           0.611111
# 3         1195  True      0.735849          0.794872           0.785714
# 4         1094  True      0.607692          0.696203           0.529412
#
#    total_sv_win_pct  bp_save_pct
# 0          0.750000     1.000000
# 1          0.608696     0.571429
# 2          0.688889     0.666667
# 3          0.792453          NaN
# 4          0.630769     0.750000
#
# [5 rows x 29 columns]

# %%
con = sqlite3.connect('/Users/julianbombard/Desktop/Data Analytics Course/Capstone/database/ATP_Tour')

df.to_sql('player_match_stats', con, index = False, if_exists = 'replace')

con.close()

# %%
final_df = df[(df['tourney_level'] != 'O') & (df['tourney_level'] != 'D')]

# %%
con = sqlite3.connect('/Users/julianbombard/Desktop/Data Analytics Course/Capstone/database/ATP_Tour')

final_df.to_sql('capstone_table', con, index = False, if_exists = 'replace')

con.close()

# %%
final_df.to_csv('csvs/final_df.csv', index = False)
